# %% [markdown]
# ### **Load Data**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score as r2
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('Housing.csv')
df
# Out:
#         price  area  bedrooms  ...  parking  prefarea furnishingstatus
# 0    13300000  7420         4  ...        2       yes        furnished
# 1    12250000  8960         4  ...        3        no        furnished
# 2    12250000  9960         3  ...        2       yes   semi-furnished
# 3    12215000  7500         4  ...        3       yes        furnished
# 4    11410000  7420         4  ...        2        no        furnished
# ..        ...   ...       ...  ...      ...       ...              ...
# 540   1820000  3000         2  ...        2        no      unfurnished
# 541   1767150  2400         3  ...        0        no   semi-furnished
# 542   1750000  3620         2  ...        0        no      unfurnished
# 543   1750000  2910         3  ...        0        no        furnished
# 544   1750000  3850         3  ...        0        no      unfurnished
#
# [545 rows x 13 columns]

# %% [markdown]
# ### **Pre-Processing data**

# %%
df.head()
# Out:
#       price  area  bedrooms  ...  parking  prefarea furnishingstatus
# 0  13300000  7420         4  ...        2       yes        furnished
# 1  12250000  8960         4  ...        3        no        furnished
# 2  12250000  9960         3  ...        2       yes   semi-furnished
# 3  12215000  7500         4  ...        3       yes        furnished
# 4  11410000  7420         4  ...        2        no        furnished
#
# [5 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.shape
# Out:
# (545, 13)

# %%
df.describe()
# Out:
#               price          area  ...     stories     parking
# count  5.450000e+02    545.000000  ...  545.000000  545.000000
# mean   4.766729e+06   5150.541284  ...    1.805505    0.693578
# std    1.870440e+06   2170.141023  ...    0.867492    0.861586
# min    1.750000e+06   1650.000000  ...    1.000000    0.000000
# 25%    3.430000e+06   3600.000000  ...    1.000000    0.000000
# 50%    4.340000e+06   4600.000000  ...    2.000000    0.000000
# 75%    5.740000e+06   6360.000000  ...    2.000000    1.000000
# max    1.330000e+07  16200.000000  ...    4.000000    3.000000
#
# [8 rows x 6 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### **Separate Data (X,Y)**

# %%
x = df.drop('price', axis=1)
y = df['price']

# %%
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
realx = x.drop(['stories','guestroom','hotwaterheating','mainroad','basement','airconditioning','prefarea','furnishingstatus'], axis=1)
print(realx)
# Out:
#      area  bedrooms  bathrooms  parking
# 0    7420         4          2        2
# 1    8960         4          4        3
# 2    9960         3          2        2
# 3    7500         4          2        3
# 4    7420         4          1        2
# ..    ...       ...        ...      ...
# 540  3000         2          1        2
# 541  2400         3          1        0
# 542  3620         2          1        0
# 543  2910         3          1        0
# 544  3850         3          1        0
#
# [545 rows x 4 columns]

# %% [markdown]
# ### **Splitting training and testing data**

# %%
X_train,X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
print("Train Shapes  : " , X_train.shape, y_train.shape)
print("Test shapes : ", X_test.shape, y_test.shape)
# Out:
# Train Shapes  :  (436, 12) (436,)
# Test shapes :  (109, 12) (109,)

# %%
categorical_columns = ['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea', 'furnishingstatus']

# %%
X_train_encoded = pd.get_dummies(X_train, columns=categorical_columns, drop_first=True)
X_test_encoded = pd.get_dummies(X_test, columns=categorical_columns, drop_first=True)

# %% [markdown]
# ### **Choosing Model**

# %%
rf = RandomForestRegressor()
rf.fit(X_train_encoded, y_train)
# Out:
# RandomForestRegressor()

# %%
x_train_rf_pred = rf.predict(X_train_encoded)
x_test_rf_pred = rf.predict(X_test_encoded)
print(x_train_rf_pred)
print(x_test_rf_pred)
# Out:
# [ 3564820.          4022830.          2840600.          4364360.
#   3719310.          6657700.          2927960.          3271800.
#   6304060.          4532220.          3244920.          2824500.
#   6018110.          5509455.          7026040.          4176585.
#   5062820.          4499180.          7437990.          4164930.
#   4654930.          2441530.          5279050.          4218130.
#   3805620.          4519130.          8383270.          8135050.
#   4409300.          3212615.          4136510.          3238970.
#   2712640.          3903060.          4098150.          2936360.
#   4615380.          3669050.          2104900.          8216559.4
#   4241090.         10547390.          8382500.          7329700.
#   4251030.          3173940.          4357080.          3662330.
#   3833130.          2674700.          5355630.          4085620.
#   4210220.          3203900.          4165840.          5627300.
# ...

# %%
#model evaluation

train_rf_MSE = mean_squared_error(x_train_rf_pred,y_train)
print("Train MSE : ", train_rf_MSE)
test_rf_MSE = mean_squared_error(x_test_rf_pred,y_test)
print("Test MSE : ", test_rf_MSE)

train_rf_r2 = r2(x_train_rf_pred,y_train)
test_rf_r2 = r2(x_test_rf_pred,y_test)
print("Train R2 : ", train_rf_r2)
print("Test R2 : ", test_rf_r2)
# Out:
# Train MSE :  182643763766.3669
# Test MSE :  1644791432609.9026
# Train R2 :  0.9351349578546584
# Test R2 :  0.2620585080297001

# %% [markdown]
# ### **Input Prediction**

# %%
input_data = (7420, 4, 2, 3, 'yes', 'no', 'no', 'no', 'yes', 2, 'yes', 'furnished')

# Manual mapping
binary_map = {'yes': 1, 'no': 0}
input_data_encoded = [
    input_data[0],  # area
    input_data[1],  # bedrooms
    input_data[2],  # bathrooms
    input_data[3],  # stories
    binary_map[input_data[4]],  # mainroad
    binary_map[input_data[5]],  # guestroom
    binary_map[input_data[6]],  # basement
    binary_map[input_data[7]],  # hotwaterheating
    binary_map[input_data[8]],  # airconditioning
    input_data[9],              # parking
    binary_map[input_data[10]], # prefarea
]

# One-hot encode 'furnishingstatus' if needed
furnishing_status_map = {
    'unfurnished': [1,0],
    'semi-furnished': [0,1],
    'furnished': [0,0]
}
furnishing_onehot = furnishing_status_map[input_data[11]]

# Combine everything
final_input = input_data_encoded + furnishing_onehot

# Convert to numpy array
input_data_array = np.asarray(final_input).reshape(1, -1)

# Predict
prediction = rf.predict(input_data_array)
print("Predicted price:", prediction)
# Out:
# Predicted price: [8094240.]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
